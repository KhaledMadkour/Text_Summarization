# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Text_Summarization_Task
# Out:
# /content/drive/My Drive/Colab Notebooks/Text_Summarization_Task

# %% [markdown]
# # **Extractive Model #2 using Text Rank Algorithm and Word embeddings**
# We  continue to discover new models for extractive text summarization.
# In this process
#
# TextRank is an extractive and unsupervised text summarization technique. Let’s take a look at the flow of the TextRank algorithm that we will be following:
#
# * The first step would be to concatenate all the text contained in the articles
#
# * Then split the text into individual sentences
# * In the next step, we will find vector representation (word embeddings) for each and every sentence
#
# * Similarities between sentence vectors are then calculated and stored in a matrix
# * The similarity matrix is then converted into a graph, with sentences as vertices and similarity scores as edges, for sentence rank calculation
# * Finally, a certain number of top-ranked sentences form the final summary

# %% [markdown]
# ## **Running preprocessing Notebook to use it's functions**

# %%
# %run Preprocessing.ipynb
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: PyArabic in /usr/local/lib/python3.6/dist-packages (0.6.7)
# Requirement already satisfied: tashaphyne in /usr/local/lib/python3.6/dist-packages (0.3.4.1)
# Requirement already satisfied: pyarabic in /usr/local/lib/python3.6/dist-packages (from tashaphyne) (0.6.7)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## **Importing Libraries**

# %%
import numpy as np
import gensim
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## **Getting The Data**

# %% [markdown]
# Just like we did In the other Notebook (Extractive Simple Model), We will read an arabic and english wikipedia articles and work on them.
#
# We will use the functions from the preprocessing notebook. Check the notebook for more informations about the functions used here.

# %%
English_article = read_wiki('https://en.wikipedia.org/wiki/20th_century')
Arabic_article = read_wiki('https://ar.wikipedia.org/wiki/%D8%A7%D9%84%D8%AD%D8%B1%D8%A8_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A%D8%A9_%D8%A7%D9%84%D8%AB%D8%A7%D9%86%D9%8A%D8%A9')

# %% [markdown]
# ## **Preprocessing**

# %% [markdown]
# ## **Split article into sentences**

# %% [markdown]
# we will use sent_tokenizer to split the string into list or sentences

# %%
English_sentences = sent_tokenize(English_article)
Arabic_sentences  = sent_tokenize(Arabic_article)

# %% [markdown]
# We will Do some basic cleaning to the data. Our preprocessing function imported from the the notebook by dafault opens what we want which are:
#
# *   Convert everything to lowercase (English article)
# *   Contraction mapping (English article)
# *   Eliminate punctuations and special characters
# *   Remove stopwords
# *   Remove Tashkel (Arabic article)
# For more information about the function check the preprocessing notebook

# %%
clean_en_sentences=[]
clean_ar_sentences=[]

for s in English_sentences:
  clean_en_sentences.append(preprocess(s , lang = 'en' , stemming = False , rm_short = True))

for s in Arabic_sentences:
  clean_ar_sentences.append(preprocess(s , lang = 'ar' , stemming = False))

# %%
print(clean_en_sentences)
print(clean_ar_sentences)
# Out:
# ['twentieth century century began january ended december', 'tenth final century millennium', 'century dominated chain events heralded significant changes world history redefine era flu pandemic world war world war nuclear power space exploration nationalism decolonization cold war post cold war conflicts intergovernmental organizations cultural homogenization developments emerging transportation communications technology poverty reduction world population growth awareness environmental degradation ecological extinction birth digital revolution enabled wide adoption mos transistors integrated circuits', 'saw great advances power generation communication medical technology late allowed near instantaneous worldwide computer communication genetic modification life', 'century saw largest transformation world order since fall rome global total fertility rates sea level rise ecological collapses increased resulting competition land dwindling resources accelerated deforestation water depletion mass extinction many world species decline population others consequences dealt', 'average global temperature earth increased celsius fahrenheit since two thirds warming occurred since rate roughly per decade', 'repercussions world wars cold war globalization crafted world people united previous time human history exemplified establishment international law international aid united nations', 'marshall plan which spent billion billion dollars rebuild economies post war nations launched pax americana', 'throughout latter half century rivalry united states soviet union created enormous tensions around world manifested various armed conflicts omnipresent danger nuclear proliferation', 'dissolution soviet union collapse european alliance heralded west end communism though century end roughly one six people earth lived communist rule mostly china rapidly rising economic geopolitical power', 'took two hundred thousand years human history world population reach billion world population reached estimated billion late global population reached billion', 'global literacy averaged', 'global campaigns eradication smallpox diseases responsible human deaths wars natural disasters combined yielded unprecedented results smallpox existed labs', 'trade improvements reversed limited set food producing techniques used since neolithic period greatly enhancing diversity foods available resulting upturn quality human nutrition', 'early century life expectancy thirty populations global lifespan averages exceeded years first time history half achieving years three decades longer century earlier', 'century first global scale total wars world powers across continents oceans world war world war', 'nationalism became major political issue world century acknowledged international law along right nations self determination official decolonization mid century related regional conflicts', 'century saw major shift way many people lived changes politics ideology economics society culture science technology medicine', 'century may seen technological scientific progress centuries combined since dawn civilization', 'terms like nationalism globalism environmentalism ideology world war genocide nuclear war entered common usage', 'scientific discoveries theory relativity quantum physics profoundly changed foundational models physical science forcing scientists realize universe complex previously believed dashing hopes fears end century last details scientific knowledge filled', 'century started horses simple automobiles freighters ended high speed rail cruise ships global commercial air travel space shuttle', 'horses pack animals every society basic form personal transportation thousands years replaced automobiles buses within decades', 'developments made possible exploitation fossil fuel resources offered energy easily portable form also caused concern pollution long term impact environment', 'humans explored space first time taking first footsteps moon', 'mass media telecommunications ...
# ['طي صفحه الرايخ الثالث', 'انشاء الامم المتحده', 'ظهور الولايات المتحده والاتحاد السوفيتي كقوات عظمي', 'الولايات المتحده المملكه المتحده الاتحاد السوفيتي فرنسا الصين بولندا كندا استراليا نيوزيلندا النرويج الدنمارك بلجيكا هولندا اليونان يوغوسلافيا تشيكوسلوفاكيا البرازيل المكسيك امبراطوريه اثيوبيا جنوب افريقيا الهند الدول العميله الفلبين منغوليا مزيد التفاصيل المانيا النازيه ايطاليا امبراطوريه اليابان رومانيا مملكه بلغاريا مملكه المجر الدول العميله مانشوكو ايطاليا كرواتيا جمهوريه سلوفاكيا صربيا الفلبين دول حاربت الطرفين فنلندا تايلاند العراق فرنسا مزيد التفاصيل جوزيف ستالين فرانكلين روزفلت ونستون تشرشل شيانج كاي شيك البير فرانسوا لوبرون فيليب بيتان رءيس فرنسا الفاشيه شارل ديغول رءيس اللجنه الفرنسيه للتحرير الوطني ادولف هتلر بينيتو موسوليني هيروهيتو هيديكي توجو قتلي عسكريون قتلي مدنيون مجموع القتلي مزيد التفاصيل قتلي عسكريون قتلي مدنيون مجموع القتلي مزيد التفاصيل الحرب العالميه حرب دوليه بدات الاول اوروبا وانتهت شاركت الغالبيه العظمي دول العالم الدول العظمي حلفين عسكريين متنازعين قوات الحلفاء ودول المحور انها الحرب الاوسع التاريخ وشارك بصوره مباشره شخص بلدا وضعت الدول الرءيسيه كافه قدراتها العسكريه والاقتصاديه والصناعيه والعلميه خدمه المجهود الحربي', 'تميزت الحرب العالميه بعدد كبير القتلي المدنيين القصف الاستراتيجي اودي بحياه حوالي شخص ومنه القنبلتان الذريتان القيتا هيروشيما وناغازاكي ادت الحرب وقوع قتيل التقديرات؛ تعد الحرب العالميه الحروب دمويه تاريخ البشريه', 'الامبراطوريه اليابانيه اعلنت الحرب جمهوريه الصين هدفت السيطره اسيا والمحيط الهادي البدايه الفعليه للحرب تعتبر الاول وذلك قامت المانيا باجتياح بولندا وتوالت بعدها اعلانات الحرب المانيا فرنسا والمملكه المتحده', 'اواخر اواءل سيطرت المانيا النازيه مساحه واسعه قاره اوروبا سلسله الحملات العسكريه وشكلت تحالف دول المحور ايطاليا واليابان اتفقت الاتحاد السوفييتي تقاسم الاراضي المجاوره بولندا وفنلندا ورومانيا ودول البلطيق', 'بقيت المعركه الاساسيه الحرب دول المحور جهه والمملكه المتحده جانب دول الكومنولث جهه اخري اضافه حمله افريقيا وحمله اخري شرق افريقيا اضافه معركه برلين الجويه وقصف لندن وحمله البلقان ومعركه المحيط الاطلسي', 'تحالف دول المحور بغزو الاتحاد السوفييتي يعرف بعمليه بارباروسا ادي اشعال الجبهه الشرقيه اكبر مسرح للحرب التاريخ كبري دول المحور حرب استنزاف وقامت اليابان بالهجوم ميناء بيرل هاربر هاجمت منطقه ملايا البريطانيه المحيط الهادي فسيطرت سريعا جزء كبير غرب المحيط الهادي', 'توقف تقدم دول المحور خسرت اليابان معركه ميدواي بالقرب ولايه هاواي الامريكيه خسرت المانيا معركه العلمين افريقيا هزمها الاتحاد السوفييتي فوزا حاسما معركه ستالينغراد تلقت المانيا سلسله هزاءم الجبهه الشرقيه الحلفاء بغزو صقليه وغزو ايطاليا ادي استسلام ايطاليا اضافه انتصارات الحلفاء المحيط الهادي ففقدت دول المحور زمام المبادره وبدات تراجعا استراتيجيا كافه الجبهات', 'الحلفاء بتحرير فرنسا يعرف بانزال نورمندي استعاد الاتحاد السوفييتي المناطق خسرها وقام بغزو المانيا وحلفاءها', 'العامين تراجعت اليابان جنوب وسط الصين حمله بورما الحلفاء بشل حركه البحريه الامبراطوريه اليابانيه وسيطرت الجزر الرءيسيه المحيط الهادي', 'انتهت الحرب اوروبا بغزو الحلفاء لالمانيا وسيطره الاتحاد السوفييتي برلين والاستسلام المشروط المانيا', 'وعقد بعدها مءتمر بوتسدام قرب برلين صدر خلاله اعلان بوتسدام وقامت الولايات المتحده بالقاء قنبلتين نوويتين هيروشيما وناغازاكي الترتيب تبع استسلام اليابان', 'غيرت الحرب العالميه الخارطه السياسيه والعسكريه والبنيه الاجتماعيه العالم ادت انشاء الامم المتحده لتعزيز التعاون الدولي ومنع الصراعات المستقبل واصبحت الدول المنتصره الحرب الولايات المتحده والاتحاد السوفياتي والصين والمملكه المتحده وفرنسا اعضاء داءمين مجلس الامن التابع للامم المتحده برزت الولايات المتحده والاتحاد السوفييتي كقوي عظمي الساحه الدوليه وانحسر نفوذ القوي الاوروبيه مهد الطريق للحرب البارده استمرت السنوات ال القادمه الدول الكبري الاوروبيه تضاءل نفوذها بدات حركات الاستقلال اسيا وافريقيا', 'اتجهت الدول تضررت الصناعه اصلاح وضعها الاقتصادي الصعيد السياسي تحديدا اوروبا بدات مرحله تكامل سعيا لتجنب العداوات تسبب الحروب للاوروبيين هويه مشتركه', 'يعتبر تاريخ بدايه الحرب الاول بدا الغزو الالماني لبولندا تلاه اعلان بريطانيا وفرنسا الحرب المانيا الثالث المحيط الهادي فيعتبر تاريخ بدايه الحرب بدايه الحرب اليابانيه الصينيه السابع البعض يعتبر تاريخ البدايه الغزو ...

# %% [markdown]
# ## **Word Embedding**

# %% [markdown]
# In this Section we will Get Word Embeddings for Both Arabic and English. These word embeddings will be used to create vectors for our sentences.

# %% [markdown]
# ### **English Word Embedding (GLOVE)**

# %% [markdown]
# GloVe, coined from Global Vectors, is a model for distributed word representation. The model is an unsupervised learning algorithm for obtaining vector representations for words. This is achieved by mapping words into a meaningful space where the distance between words is related to semantic similarity.
#
# It can be downloaded from [Here](https://nlp.stanford.edu/data/glove.6B.zip)

# %%
# Extract word vectors
english_embeddings = {}
f = open('/content/drive/My Drive/Colab Notebooks/Text_Summarization_Task/Word_Embedding/glove/glove.6B.100d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    english_embeddings[word] = coefs
f.close()

# %% [markdown]
# ### **Arabic Word Embedding (AraVec)**

# %% [markdown]
# AraVec is one of the few Arabic WordEmbeddings out There you can get it and Read more about it from here:
# [Github](https://github.com/bakrianoo/aravec)
#
# I am using the 300 vec size Wikipedia SkipGram:
# [Here](https://bakrianoo.sfo2.digitaloceanspaces.com/aravec/full_uni_sg_300_wiki.zip)

# %%
t_model = gensim.models.Word2Vec.load('/content/drive/My Drive/Colab Notebooks/Text_Summarization_Task/Word_Embedding/AraVec/full_uni_sg_300_wiki.mdl')
arabic_embedding= t_model.wv
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ## **Vector Representation of Sentences**

# %% [markdown]
# Now We will create our Vector representation of the sentences:
#
# We will fetch vectors for the constituent words in a sentence and then take mean/average of those vectors to arrive at a consolidated vector for the sentence.

# %%
def eng_vec_rep(clean_sentences):
  sentence_vectors = []
  for i in clean_sentences:
    if len(i) != 0:
      v = sum([word_embeddings.get(w, np.zeros((100,))) for w in i.split()])/(len(i.split())+0.001)
    else:
      v = np.zeros((100,))
    sentence_vectors.append(v)
  return sentence_vectors

def ar_vec_rep(clean_sentences):
  sentence_vectors = []
  for i in clean_sentences:
    if len(i) != 0:
      v = 0
      for w in i.split():
        if w in arabic_embedding:
          v+= arabic_embedding[w]
        else:
          v+= np.zeros((300,))
      v/= len(i.split())+0.001
    else:
      v = np.zeros((300,))
    sentence_vectors.append(v)
  return sentence_vectors

en_sentence_vectors = eng_vec_rep(clean_en_sentences)
ar_sentence_vectors = ar_vec_rep(clean_ar_sentences)

# %% [markdown]
# ## **Similarity matrix**

# %% [markdown]
# The next step is to find similarities between the sentences, and we will use the cosine similarity approach for this challenge. Let’s create an empty similarity matrix for this task and populate it with cosine similarities of the sentences.
#
# Let’s first define a zero matrix of dimensions (n * n).  We will initialize this matrix with cosine similarity scores of the sentences. Here, n is the number of sentences.

# %%
# similarity matrix
en_sim_mat = np.zeros([len(clean_en_sentences), len(clean_en_sentences)])
ar_sim_mat = np.zeros([len(clean_ar_sentences), len(clean_ar_sentences)])

# %% [markdown]
# We will use Cosine Similarity to compute the similarity between a pair of sentences.
# And initialize the matrix with cosine similarity scores.

# %%
from sklearn.metrics.pairwise import cosine_similarity

#For English
for i in range(len(clean_en_sentences)):
  for j in range(len(clean_en_sentences)):
    if i != j:
      en_sim_mat[i][j] = cosine_similarity(en_sentence_vectors[i].reshape(1,100), en_sentence_vectors[j].reshape(1,100))[0,0]

#For Arabic
for i in range(len(clean_ar_sentences)):
  for j in range(len(clean_ar_sentences)):
    if i != j:
      ar_sim_mat[i][j] = cosine_similarity(ar_sentence_vectors[i].reshape(1,300), ar_sentence_vectors[j].reshape(1,300))[0,0]

# %% [markdown]
# ## **Applying PageRank Algorithm**

# %% [markdown]
# Before proceeding further, let’s convert the similarity matrix sim_mat into a graph. The nodes of this graph will represent the sentences and the edges will represent the similarity scores between the sentences. On this graph, we will apply the PageRank algorithm to arrive at the sentence rankings.

# %%
import networkx as nx

#for English
en_nx_graph = nx.from_numpy_array(en_sim_mat)
en_scores = nx.pagerank(en_nx_graph)

#for Arabic
ar_nx_graph = nx.from_numpy_array(ar_sim_mat)
ar_scores = nx.pagerank(ar_nx_graph)

# %% [markdown]
# ## **Summary Extraction**

# %% [markdown]
#  it’s time to extract the top N sentences based on their rankings for summary generation.

# %%
#english
en_ranked_sentences = sorted(((en_scores[i],s) for i,s in enumerate(English_sentences)), reverse=True)

#arabic
ar_ranked_sentences = sorted(((ar_scores[i],s) for i,s in enumerate(Arabic_sentences)), reverse=True)

# %% [markdown]
# ## **Results**

# %% [markdown]
# English

# %%
# Printing top 5 sentences as the summary
for i in range(5):
  print(en_ranked_sentences[i][1])
# Out:
# The period was marked by a new arms race as the USSR became the second nation to develop nuclear weapons, which were produced by both sides in sufficient numbers to end most human life on the planet had a large-scale nuclear exchange ever occurred.
# Western Europe was rebuilt with the aid of the American Marshall Plan, resulting in a major post-war economic boom, and many of the affected nations became close allies of the United States.
# The dissolution of the Soviet Union in 1991 after the collapse of its European alliance was heralded by the West as the end of communism, though by the century's end roughly one in six people on Earth lived under communist rule, mostly in China which was rapidly rising as an economic and geopolitical power.
# The 20th century was dominated by a chain of events that heralded significant changes in world history as to redefine the era: flu pandemic, World War I and World War II, nuclear power and space exploration, nationalism and decolonization, the Cold War and post-Cold War conflicts; intergovernmental organizations and cultural homogenization through developments in emerging transportation and communications technology; poverty reduction and world population growth, awareness of environmental degradation, ecological extinction;[3][4] and the birth of the Digital Revolution, enabled by the wide adoption of MOS transistors and integrated circuits.
# [5]
# The repercussions of the World Wars, Cold War and Globalization crafted a world where people are more united than any previous time in human history, as exemplified by the establishment of international law, international aid, and the United Nations.

# %% [markdown]
# Arabic

# %%
# Printing top 5 sentences as the summary
for i in range(5):
  print(ar_ranked_sentences[i][1])
# Out:
# في الأول من سبتمبر هاجمت القوات الألمانية بولندا بحجة أن بولندا شنت هجمات على الأراضي الألمانية[64]، وبعد يومين، في 3 سبتمبر 1939 ونتيجة لتجاهل ألمانيا الإنذار البريطاني بوقف العمليات العسكرية في بولندا
# أعلنت كل من المملكة المتحدة وفرنسا الحرب على ألمانيا وتبعهما في إعلان الحرب دول الكومنولث البريطاني وهي كل من أستراليا (في 3 سبمتمر) ونيوزلندا (3 سبتمبر) وجنوب أفريقيا (6 سبمتبر) وكندا (10 سبتمبر)[13]، وبدأت بريطانيا بإرسال جيوشها إلى فرنسا، إلا أن هذه الجيوش لم تقدم أي مساعدة فعلية للبولنديين خلال الغزو، وبقيت الحدود الفرنسية الألمانية هادئة، وبدأت ما تعرف بالحرب الزائفة[65]، حيث اكتفت الجيوش بفرض حصار اقتصادي على ألمانيا مما دفع ألمانيا بمهاجمة السفن التجارية في المحيط الأطلسي وبداية معركة الأطلسي.
# في 17 سبتمبر 1939 قام الاتحاد السوفيتي بمهاجمة بولندا[64][66]، وفي 27 سبتمبر 1939 استسلمت بولندا للألمان مع وجود جيوب للمقاومة[67]، وفي 6 أكتوبر تم إعلان الاستسلام النهائي لبولندا بعد معركة كوك[68][69]، وتم تشكيل حكومة منفى في لندن تابعت لاحقاً إدارة العمليات القتالية لجيش الوطن - حركة المقاومة البولندية - والتي استمرت حتى نهاية الحرب[70]، حيث كانت الحكومة البولندية أثناء الحرب قد رحلت قرابة 100,000 جندي إلى رومانيا و دول البلطيق، في حين تقاسمت كل من ألمانيا والاتحاد السوفيتي الأراضي البولندية[64].
# حتى استسلام فرنسا لم يساعد قوات المحور كثيرا في معارك البحر المتوسط، التي كانت توصف كمأساة للأسطول الحربي الإيطالي والأسطول الفرنسي الفيشي (المواليين للمحور)، حيث تأثر هذان الأسطولان بأضرار بالغة من الأسطول البريطاني والأسترالي، خاصة في معارك:
# على صعيد آخر، كانت المملكة اليوغسلافية تعاني من مشكلة عدم وجود قيادة لها، وقد تم تنصيب الأمير بافل كارادوفيتش وصيا على العرش، والذي قام بعمل اتفاقية مع ألمانيا في 25 مارس 1941، وقد تم ترجيح سبب الاتفاقية بأن هتلر قام بوعد اليوغسلافيين بأنه لو سمحوا له بأن يستخدم أراضي يوغوسلافيا للهجوم على اليونان، سيقوم بإعطائهم مناطق من شمال اليونان ويشمل ذلك "سالونيك"، بالرغم من ذلك، وبعد احتجاج الرأي العام اليوغسلافي وقيام المظاهرات ضد الاتفاقية، فقام الجنرال دوسان سيموفيتش بانقلاب عسكري ليتولى الحكم بدلا من الوصي على العرش ليخلص يوغوسلافيا من الفاشيين.
# كل ذلك أدى إلى عدم وجود مواجهة خلال المعركة بين جيوش المشاة، لقد جلبت الحرب الجوية أنظار العالم، فامتدت المعارك حتى الأطلسي، بعدها استخدمت بريطانيا بعض القوات الخاصة "كوماندوز" في ضرب بعض المناطق في أوروبا المحتلة، الأمر الذي جعل تشرشل يفخر بنفسه ويشيد بأفراد الجيش البريطاني قائلا " لم يحدث أبدا في مجال الصراعات الإنسانية أن خضعت الأكثرية للأقلية ".
# غير أن القوات الألمانية تابعت تقدمها باتجاه فرنسا منذ 13 مايو، وذلك عبر غابات آدرين ملتفة على خط ماجينو، وجاء ذلك التوغل نتيجة خطأ فادح من الفرنسيين عندما أهملوا حماية هذه المنطقة، على اعتبار أنها مجاورة لدول محايدة، ولاعتقادهم بأن طبيعة هذه المنطقة الجغرافية تجعل من المستحيل أن تتحرك بها الدروع الحربية الألمانية[80]، مما سمح للألمان بتحقيق انتصارات عديدة، ودفع الفرنسيين والبريطانيين إلى القيام بعملية إخلاء جماعي في دونكيرك - عملية دينامو - استمر من 27 مايو إلى 4 يونيو تاركين خلفهم معداتهم الثقيلة[83]، وفي 10 يونيو بدء الغزو الإيطالي لفرنسا[84]، وفي 14 يونيو سقطت العاصمة الفرنسية باريس بيد الألمان[85]، وفي 16 يونيو استقال رئيس الوزراء الفرنسي بول رينو، وخلفه فيليب بيتان[86].

# %% [markdown]
# ## **Observations**

# %% [markdown]
# This model is much better than the simple previous one, it uses word embeddings to get a better meaning of words hence give better score to each sentence and rank.
